# %% [markdown]
# <a href="https://www.kaggle.com/code/lz82117/cdp-background-research?scriptVersionId=97332064" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ## Imports

# %%
# standard libs
import os
import pandas as pd
import numpy as np

print(os.getcwd())
# Out:
# /kaggle/working

# %% [markdown]
# ## Data
#
# ### Import Data

# %%
# import cities response df
cities21_df = pd.read_csv("../input/cdp2021/2021_Cities_Water_Security_Risks.csv")
cities20_df = pd.read_csv("../input/cdp-unlocking-climate-solutions/Cities/Cities Responses/2020_Full_Cities_Dataset.csv")
cities19_df = pd.read_csv("../input/cdp-unlocking-climate-solutions/Cities/Cities Responses/2019_Full_Cities_Dataset.csv")

# %% [markdown]
# ### Data Cleaning & EDA

# %%
risk21=cities21_df.rename(columns={'Account Name': 'City'})
risk21.dropna(subset=['Water security risk drivers'],inplace=True)
risk21.drop_duplicates(inplace=True)

cities20_df = cities20_df[cities20_df['Question Number'] == '14.2a']\
    .rename(columns={'Organization': 'City'})
cities20_df.dropna(subset=['Response Answer'],inplace=True)
risk20=cities20_df.pivot_table(index=['Account Number', 'City', 'Row Number'],
                                     columns='Column Name', 
                                     values='Response Answer',
                                     aggfunc=lambda x: ' '.join(x)).reset_index()
risk20.drop_duplicates(inplace=True)

cities19_df = cities19_df[
    cities19_df['Question Name'] == 
    'Please identify the risks to your city’s water supply as well as the timescale and level of risk.']\
    .rename(columns={'Organization': 'City'})
cities19_df.dropna(subset=['Response Answer'],inplace=True)
risk19=cities19_df.pivot_table(index=['Account Number', 'City', 'Row Number'],
                                     columns='Column Name', 
                                     values='Response Answer',
                                     aggfunc=lambda x: ' '.join(x)).reset_index()
risk19['Risks'][(risk19['Risks']=='Inadequate or ageing infrastructure')]='Inadequate or ageing water supply infrastructure'
risk19=risk19.rename(columns={'Risks':'Water security risk drivers'})
risk19.drop_duplicates(inplace=True)
risk21.head()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Questionnaire Name  Account Number                     City  \
# 0        Cities 2021            1093      City of Atlanta, GA
# 1        Cities 2021            1093      City of Atlanta, GA
# 2        Cities 2021            1184       City of Austin, TX
# 3        Cities 2021            1499  Ajuntament de Barcelona
# 4        Cities 2021            1499  Ajuntament de Barcelona
#
#                     Country     CDP Region       ParentSection       Section  \
# 0  United States of America  North America  14. Water Security  Water Supply
# 1  United States of America  North America  14. Water Security  Water Supply
# 2  United States of America  North America  14. Water Security  Water Supply
# 3                     Spain         Europe  14. Water Security  Water Supply
# 4                     Spain         Europe  14. Water Security  Water Supply
#
#   Question Number                                      Question Name  \
# 0           14.2a  Please identify the risks to your city’s water...
# 1           14.2a  Please identify the risks to your city’s water...
# 2           14.2a  Please identify the risks to your city’s water...
# 3           14.2a  Please identify the risks to your city’s water...
# 4           14.2a  Please identify the risks to your city’s water...
#
#    Row Number Water security risk drivers  Anticipated timescale  \
# 0           1      Increased water stress   Short-term (by 2025)
# 1           2         Higher water prices                Current
# 2           1      Increased water stress   Short-term (by 2025)
# 3           1      Increased water stress                Current
# 4           2     Declining water quality  Medium-term (by 2050)
#
#   Estimated magnitude of potential impact Estimated probability of impact  \
# 0                                 Serious                             NaN
# 1                                 Serious                             NaN
# 2                       Extremely serious                            High
# 3                                 Serious                     Medium-high
# 4                            Less Serious                          Medium
#
#                                     Risk description
# 0  The city depends on one river for water supply...
# 1  The water cost burden is felt across all ZIP c...
# 2  Central Texas is drought prone and we depend o...
# 3  The downscaling of the climate projections at ...
# 4  A reduction in water resources availability  c...

# %%
risk20.head()
# Out:
# Column Name  Account Number                     City  Row Number  \
# 0                      1184           City of Austin           1
# 1                      1499  Ajuntament de Barcelona           1
# 2                      1499  Ajuntament de Barcelona           2
# 3                      1499  Ajuntament de Barcelona           3
# 4                      1499  Ajuntament de Barcelona           4
#
# Column Name  Anticipated timescale Estimated magnitude of potential impact  \
# 0             Short-term (by 2025)                       Extremely serious
# 1                          Current                                 Serious
# 2            Medium-term (by 2050)                            Less Serious
# 3                          Current                                 Serious
# 4                          Current                                 Serious
#
# Column Name Estimated probability of impact  \
# 0                                      High
# 1                               Medium-high
# 2                                    Medium
# 3                               Medium-high
# 4                               Medium-high
#
# Column Name                                   Risk description  \
# 0            Central Texas is drought prone and we depend o...
# 1            The downscaling of the climate projections at ...
# 2            A reduction in water resources availability  c...
# 3            In terms of water supply, rivers floods could ...
# 4            Climate Plan vulnerability assessement showed ...
#
# Column Name Water security risk drivers
# 0                Increased water stress
# 1                Increased water stress
# 2               Declining water quality
# 3                 Severe weather events
# 4              Increased water scarcity

# %%
risk19.head()
# Out:
# Column Name  Account Number                     City  Row Number  \
# 0                      1093          City of Atlanta           1
# 1                      1093          City of Atlanta           2
# 2                      1184           City of Austin           1
# 3                      1499  Ajuntament de Barcelona           1
# 4                      1499  Ajuntament de Barcelona           2
#
# Column Name Estimated magnitude Estimated timescale  \
# 0                       Serious          Short-term
# 1                       Serious             Current
# 2             Extremely serious          Short-term
# 3                  Less Serious             Current
# 4                  Less Serious         Medium-term
#
# Column Name                                   Risk description  \
# 0            The city depends on one river for water supply...
# 1            The water cost burden is felt across all ZIP c...
# 2            Central Texas is drought prone and we depend o...
# 3            The downscaling of the climate projections at ...
# 4            A reduction in water resources availability  c...
#
# Column Name Water security risk drivers
# 0                Increased water stress
# 1                   Higher water prices
# 2                Increased water stress
# 3                Increased water stress
# 4               Declining water quality

# %%
def countrisk(df):
    df1=pd.crosstab(index=df['Water security risk drivers'], columns='count').sort_values(by='count',ascending=False)
    if sum(df1.index.isin(['Question not applicable']))>0:df1.drop('Question not applicable',inplace=True)
    df1=df1[df1['count']>5]
    return(df1)

# %%
df21=countrisk(risk21)
df21.plot.pie(y='count',figsize=(6,6),legend=False)

# %%
df20=countrisk(risk20)
df20.plot.pie(y='count',figsize=(6,6),legend=False)

# %%
df19=countrisk(risk19)
df19.plot.pie(y='count',figsize=(6,6),legend=False)

# %%
df21=df21.rename(columns={'count': 'count21'})
df20=df20.rename(columns={'count': 'count20'})
df19=df19.rename(columns={'count': 'count19'})
outer_merged = pd.merge(df21, df20, how="outer",on='Water security risk drivers')
outer_merged = pd.merge(outer_merged , df19, how="outer",on='Water security risk drivers')
outer_merged
# Out:
# col_0                                             count21  count20  count19
# Water security risk drivers
# Increased water stress                              250.0    209.0    263.0
# Declining water quality                             237.0    163.0    223.0
# Inadequate or ageing water supply infrastructure    197.0    140.0    161.0
# Increased water demand                              160.0     96.0    103.0
# Drought                                             148.0     88.0     78.0
# Increased water scarcity                            147.0     73.0     77.0
# Severe weather events                               101.0     65.0     65.0
# Higher water prices                                  89.0     63.0     75.0
# Pollution incidents                                  46.0     20.0      NaN
# Change in land-use                                   39.0     24.0     25.0
# Environmental regulations                            36.0     23.0      NaN
# Energy supply issues                                 32.0     18.0     14.0
# Rationing of municipal water supply                  25.0     17.0     11.0
# Unauthorised/unregistered water connections          20.0      7.0      NaN
# Ecosystem vulnerability                              20.0     10.0      NaN
# Increased levels of plastic in freshwater bodies     16.0      7.0      NaN
# Water infestation/disease                            15.0      7.0      NaN
# Regulatory                                            NaN      NaN     27.0

# %%
idx=risk21['Water security risk drivers'].isin(outer_merged.index[0:5].tolist())
risk5_2021=risk21[idx][['CDP Region','City','Water security risk drivers']].drop_duplicates()
risk5=risk5_2021.pivot_table(index=['CDP Region'],columns='Water security risk drivers',values='City',
                             aggfunc=lambda x: len(x),margins=True).sort_values(by='All',ascending=True)
risk5
# Out:
# Water security risk drivers  Declining water quality  Drought  \
# CDP Region
# Middle East                                      2.0      NaN
# South and West Asia                              3.0      1.0
# East Asia                                        7.0      5.0
# Africa                                          18.0     12.0
# Southeast Asia and Oceania                      27.0     15.0
# Europe                                          54.0     34.0
# North America                                   49.0     33.0
# Latin America                                   65.0     45.0
# All                                            225.0    145.0
#
# Water security risk drivers  Inadequate or ageing water supply infrastructure  \
# CDP Region
# Middle East                                                               2.0
# South and West Asia                                                       4.0
# East Asia                                                                 7.0
# Africa                                                                   24.0
# Southeast Asia and Oceania                                               20.0
# Europe                                                                   27.0
# North America                                                            53.0
# Latin America                                                            53.0
# All                                                                     190.0
#
# Water security risk drivers  Increased water demand  Increased water stress  \
# CDP Region
# Middle East                                     2.0                     4.0
# South and West Asia                             4.0                     5.0
# East Asia                                       4.0                     9.0
# Africa                                         14.0                    13.0
# Southeast Asia and Oceania                     23.0                    19.0
# Europe                                         27.0                    46.0
# North America                                  28.0                    66.0
# Latin America                                  54.0                    79.0
# All                                           156.0                   241.0
#
# Water security risk drivers  All
# CDP Region
# Middle East                   10
# South and West Asia           17
# East Asia                     32
# Africa                        81
# Southeast Asia and Oceania   104
# Europe                       188
# North America                229
# Latin America                296
# All                          957

# %%
risk5.iloc[:,0:5].plot.barh( stacked=True,
        title='Stacked Bar Graph by Region')
