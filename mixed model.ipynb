# %% [markdown]
# **water shortage likelihood prediction**

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
import warnings
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import naive_bayes
from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_selection import SelectKBest, mutual_info_classif
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Load and view aquastat data set

# %%
df = pd.read_csv('https://mda-project-poland.s3.eu-west-3.amazonaws.com/ultimate+aquastat+(flat).csv')  # will be used for Time series analysis
df_GDP = pd.read_csv('https://mda-project-poland.s3.eu-west-3.amazonaws.com/GDP.csv')
df_2018 = df.loc[df['Year'] == 2018]  # will be used for classification

# %%
table_2018 = pd.pivot_table(data=df_2018,values='Value',index='Area',columns='Variable Name')

# drop undernourishment and add GDP  
table_2018 = table_2018.drop('Prevalence of undernourishment (3-year average)', axis=1)  # TODO download correct data from AQUASTAT instead of dropping here
df_GDP_2018 = df_GDP.loc[df_GDP['Year'] == 2018] 
table_GDP_2018 = pd.pivot_table(data=df_GDP_2018,values='Value',index='Area',columns='Variable Name')

table_2018 = table_2018.merge(table_GDP_2018, how='inner', on='Area')

table_2018.head()
# Out:
# Variable Name                     Agricultural water withdrawal as % of total renewable water resources  \
# Area
# Afghanistan                                                               30.613807
# Argentina                                                                  3.187483
# Australia                                                                  2.444073
# Azerbaijan                                                                32.406633
# Bolivia (Plurinational State of)                                           0.334495
#
# Variable Name                     Agriculture, value added (% GDP)  \
# Area
# Afghanistan                                              22.440899
# Argentina                                                 6.097129
# Australia                                                 2.121597
# Azerbaijan                                                5.212381
# Bolivia (Plurinational State of)                         11.481924
#
# Variable Name                     Average Temperature  \
# Area
# Afghanistan                                     14.55
# Argentina                                       14.99
# Australia                                       22.58
# Azerbaijan                                      14.16
# Bolivia (Plurinational State of)                20.80
#
# Variable Name                     Environmental Flow Requirements  \
# Area
# Afghanistan                                                 28.29
# Argentina                                                  515.80
# Australia                                                  243.30
# Azerbaijan                                                  12.03
# Bolivia (Plurinational State of)                           396.60
#
# Variable Name                     GDP per capita  \
# Area
# Afghanistan                           563.983834
# Argentina                           11601.890080
# Australia                           58689.490190
# Azerbaijan                           4729.900727
# Bolivia (Plurinational State of)     3592.084429
#
# Variable Name                     Industry, value added to GDP  \
# Area
# Afghanistan                                       4.800000e+09
# Argentina                                         1.070000e+11
# Australia                                         3.020000e+11
# Azerbaijan                                        2.400000e+10
# Bolivia (Plurinational State of)                  9.720000e+09
#
# Variable Name                     Long-term average annual precipitation in volume  \
# Area
# Afghanistan                                                              213.48522
# Argentina                                                               1643.21640
# Australia                                                               4133.81148
# Azerbaijan                                                                38.71020
# Bolivia (Plurinational State of)                                        1258.97268
#
# Variable Name                     MDG 7.5. Freshwater withdrawal as % of total renewable water resources  \
# Area
# Afghanistan                                                               31.045461
# Argentina                                                                  4.301333
# Australia                                                                  2.354494
# Azerbaijan                                                                35.088681
# Bolivia (Plurinational State of)                                           0.363763
#
# Variable Name                     National Rainfall Index (NRI)  \
# Area
# Afghanistan                                               185.0
# Argentina                                                1062.0
# Australia                                                 717.1
# Azerbaijan                                                459.7
# Bolivia (Plurinational State of)                         1503.0
#
# Variable Name                     Population density  \
# Area
# Afghanistan                                56.937048
# Argentina                                  15.954953
# Australia                                   3.216309
# Azerbaijan                                114.890727
# Bolivia (Plurinational State of)           10.334379
#
# Variable Name                     SDG 6.4.1. Industrial Water Use Efficiency  \
# Area
# Afghanistan                                                        31.220059
# Argentina                                                          32.596217
# Australia                                                          91.638244
# Azerbaijan                                                         50.317916
# Bolivia (Plurinational State of)                                  281.746033
#
# Variable Name                     SDG 6.4.1. Irrigated Agriculture Water Use Efficiency  \
# Area
# Afghanistan                                                                0.102132
# Argentina                                                                  0.152694
# Australia                                                                  0.418891
# Azerbaijan                                                                 0.159418
# Bolivia (Plurinational State of)                                           0.248811
#
# Variable Name                     SDG 6.4.1. Services Water Use Efficiency  \
# Area
# Afghanistan                                                      57.683901
# Argentina                                                        62.519941
# Australia                                                       405.626370
# Azerbaijan                                                       46.604281
# Bolivia (Plurinational State of)                                140.699591
#
# Variable Name                     SDG 6.4.1. Water Use Efficiency  \
# Area
# Afghanistan                                              0.935917
# Argentina                                               13.244872
# Australia                                               70.079929
# Azerbaijan                                               3.870952
# Bolivia (Plurinational State of)                        13.711080
#
# Variable Name                     SDG 6.4.2. Water Stress  \
# Area
# Afghanistan                                     54.757019
# Argentina                                       10.456664
# Australia                                        4.657865
# Azerbaijan                                      53.729300
# Bolivia (Plurinational State of)                 1.177001
#
# Variable Name                     Services, value added to GDP  \
# Area
# Afghanistan                                       1.060000e+10
# Argentina                                         3.010000e+11
# Australia                                         1.010000e+12
# Azerbaijan                                        1.680000e+10
# Bolivia (Plurinational State of)                  2.060000e+10
#
# Variable Name                     Total population with access to safe drinking-water (JMP)  \
# Area
# Afghanistan                                                                    55.3
# Argentina                                                                      99.1
# Australia                                                                     100.0
# Azerbaijan                                                                     87.0
# Bolivia (Plurinational State of)                                               90.0
#
# Variable Name                     Total renewable water resources per capita  \
# Area
# Afghanistan                                                      1757.509385
# Argentina                                                       19752.418500
# Australia                                                       19760.502710
# Azerbaijan                                                       3485.086793
# Bolivia (Plurinational State of)                                50558.691150
#
# Variable Name                     Total water withdrawal per capita  \
# Area
# Afghanistan                                              548.072294
# Argentina                                                851.646091
# Australia                                                697.308780
# Azerbaijan                                              1222.870974
# Bolivia (Plurinational State of)                         183.913845
#
# Variable Name                     Gross Domestic Product (GDP)
# Area
# Afghanistan                                       1.798697e+10
# Argentina                                         5.198717e+11
# Australia                                         1.458953e+12
# Azerbaijan                                        4.711248e+10
# Bolivia (Plurinational State of)                  4.028765e+10

# %%
table = pd.pivot_table(data=df,values='Value',index=['Area','Year'],columns='Variable Name')

# %%
df=pd.DataFrame(table.to_records())

# %%
df
# Out:
#             Area    Year  \
# 0    Afghanistan  1992.0
# 1    Afghanistan  1997.0
# 2    Afghanistan  2002.0
# 3    Afghanistan  2007.0
# 4    Afghanistan  2012.0
# ..           ...     ...
# 254     Zimbabwe  2002.0
# 255     Zimbabwe  2007.0
# 256     Zimbabwe  2012.0
# 257     Zimbabwe  2017.0
# 258     Zimbabwe  2018.0
#
#      Agricultural water withdrawal as % of total renewable water resources  \
# 0                                            35.498101
# 1                                            31.427856
# 2                                            30.613807
# 3                                            30.613807
# 4                                            30.613807
# ..                                                 ...
# 254                                          16.590000
# 255                                          14.650000
# 256                                          13.878125
# 257                                          13.850000
# 258                                          15.205350
#
#      Agriculture, value added (% GDP)  Average Temperature  \
# 0                           54.207106                12.61
# 1                           62.416768                12.86
# 2                           45.134344                13.91
# 3                           35.265942                13.80
# 4                           28.556142                13.25
# ..                                ...                  ...
# 254                         24.816602                21.78
# 255                         22.393849                21.95
# 256                          8.044518                21.84
# 257                          8.340969                21.65
# 258                          8.304691                22.03
#
#      Environmental Flow Requirements  GDP per capita  \
# 0                             28.290      248.518890
# 1                             28.290      164.092893
# 2                             28.290      194.958382
# 3                             28.290      389.985586
# 4                             28.290      694.885618
# ..                               ...             ...
# 254                            9.348      657.209841
# 255                            9.348      522.006175
# 256                            9.348     1163.418688
# 257                            9.348     1333.395663
# 258                            9.348     1437.425967
#
#      Industry, value added to GDP  \
# 0                    5.530000e+08
# 1                    4.220000e+08
# 2                    9.150000e+08
# 3                    2.600000e+09
# 4                    4.360000e+09
# ..                            ...
# 254                  8.860000e+08
# 255                  1.900000e+09
# 256                  3.840000e+09
# 257                  4.190000e+09
# 258                  4.490000e+09
#
#      Long-term average annual precipitation in volume  \
# 0                                           213.48522
# 1                                           213.48522
# 2                                           213.48522
# 3                                           213.48522
# 4                                           213.48522
# ..                                                ...
# 254                                         256.72932
# 255                                         256.72932
# 256                                         256.72932
# 257                                         256.72932
# 258                                         256.72932
#
#      MDG 7.5. Freshwater withdrawal as % of total renewable water resources  \
# 0                                            35.910480
# 1                                            31.852952
# 2                                            31.045461
# 3                                            31.045461
# 4                                            31.045461
# ..                                                 ...
# 254                                          21.025000
# 255                                          17.850000
# 256                                          17.303125
# 257                                          16.695000
# 258                                          18.856900
#
#      ...  Prevalence of undernourishment (3-year average)  \
# 0    ...                                             29.5
# 1    ...                                             45.6
# 2    ...                                             47.8
# 3    ...                                             33.3
# 4    ...                                             24.7
# ..   ...                                              ...
# 254  ...                                             40.4
# 255  ...                                             42.1
# 256  ...                                             41.3
# 257  ...                                             50.9
# 258  ...                                             51.3
#
#      SDG 6.4.1. Industrial Water Use Efficiency  \
# 0                                     25.311413
# 1                                      9.091408
# 2                                     11.426285
# 3                                     20.815284
# 4                                     23.227115
# ..                                          ...
# 254                                    3.517161
# 255                                    9.827918
# 256                                   32.078736
# 257                                   49.212382
# 258                                   50.133261
#
#      SDG 6.4.1. Irrigated Agriculture Water Use Efficiency  \
# 0                                             0.092143
# 1                                             0.085820
# 2                                             0.074770
# 3                                             0.110353
# 4                                             0.103801
# ..                                                 ...
# 254                                           0.061777
# 255                                           0.044898
# 256                                           0.040073
# 257                                           0.045300
# 258                                           0.042805
#
#      SDG 6.4.1. Services Water Use Efficiency  \
# 0                                   10.237171
# 1                                    7.763338
# 2                                   15.252615
# 3                                   26.876683
# 4                                   47.639557
# ..                                        ...
# 254                                  9.589117
# 255                                  8.137430
# 256                                 19.655079
# 257                                 27.194410
# 258                                 21.585173
#
#      SDG 6.4.1. Water Use Efficiency  SDG 6.4.2. Water Stress  \
# 0                           0.240400                63.337788
# 1                           0.194590                56.181246
# 2                           0.285607                54.757019
# 3                           0.549846                54.757019
# 4                           0.770774                54.757019
# ..                               ...                      ...
# 254                         1.641160                39.476155
# 255                         1.597468                33.514833
# 256                         4.396704                32.488030
# 257                         5.209213                31.346226
# 258                         4.830176                35.405370
#
#      Services, value added to GDP  \
# 0                    9.950000e+08
# 1                    6.530000e+08
# 2                    1.470000e+09
# 3                    4.030000e+09
# 4                    1.070000e+10
# ..                            ...
# 254                  4.770000e+09
# 255                  3.100000e+09
# 256                  9.920000e+09
# 257                  1.390000e+10
# 258                  1.540000e+10
#
#      Total population with access to safe drinking-water (JMP)  \
# 0                                                 21.3
# 1                                                 25.0
# 2                                                 33.8
# 3                                                 42.6
# 4                                                 51.6
# ..                                                 ...
# 254                                               79.4
# 255                                               78.4
# 256                                               77.5
# 257                                               76.9
# 258                                               76.9
#
#      Total renewable water resources per capita  \
# 0                                   4510.012947
# 1                                   3374.984489
# 2                                   2890.609479
# 3                                   2410.653428
# 4                                   2096.505623
# ..                                          ...
# 254                                 1673.039553
# 255                                 1631.864171
# 256                                 1524.953965
# 257                                 1404.830298
# 258                                 1385.156469
#
#      Total water withdrawal per capita
# 0                          1619.567311
# 1                          1075.032191
# 2                           899.030431
# 3                           751.752659
# 4                           653.786919
# ..                                 ...
# 254                         351.756566
# 255                         291.287755
# 256                         263.898049
# 257                         234.543442
# 258                         261.197570
#
# [259 rows x 22 columns]

# %%
# drop undernourishment and add GDP  
df = df.drop('Prevalence of undernourishment (3-year average)', axis=1)  # TODO download correct data from AQUASTAT instead of dropping here
table_GDP = pd.pivot_table(data=df_GDP,values='Value',index=['Area','Year'],columns='Variable Name')
df_GDP=pd.DataFrame(table_GDP.to_records())
df_GDP
# Out:
#             Area    Year  Gross Domestic Product (GDP)
# 0    Afghanistan  1992.0                  3.444711e+09
# 1    Afghanistan  1997.0                  2.924589e+09
# 2    Afghanistan  2002.0                  4.141524e+09
# 3    Afghanistan  2007.0                  9.412162e+09
# 4    Afghanistan  2012.0                  1.913650e+10
# ..           ...     ...                           ...
# 254     Zimbabwe  2002.0                  8.215468e+09
# 255     Zimbabwe  2007.0                  6.958295e+09
# 256     Zimbabwe  2012.0                  1.711485e+10
# 257     Zimbabwe  2017.0                  2.204090e+10
# 258     Zimbabwe  2018.0                  2.431156e+10
#
# [259 rows x 3 columns]

# %%
df = df.merge(df_GDP, how='inner', on=['Area','Year'])
#df.drop(['Gross Domestic Product (GDP)_y'], axis=1)
df
# Out:
#             Area    Year  \
# 0    Afghanistan  1992.0
# 1    Afghanistan  1997.0
# 2    Afghanistan  2002.0
# 3    Afghanistan  2007.0
# 4    Afghanistan  2012.0
# ..           ...     ...
# 254     Zimbabwe  2002.0
# 255     Zimbabwe  2007.0
# 256     Zimbabwe  2012.0
# 257     Zimbabwe  2017.0
# 258     Zimbabwe  2018.0
#
#      Agricultural water withdrawal as % of total renewable water resources  \
# 0                                            35.498101
# 1                                            31.427856
# 2                                            30.613807
# 3                                            30.613807
# 4                                            30.613807
# ..                                                 ...
# 254                                          16.590000
# 255                                          14.650000
# 256                                          13.878125
# 257                                          13.850000
# 258                                          15.205350
#
#      Agriculture, value added (% GDP)  Average Temperature  \
# 0                           54.207106                12.61
# 1                           62.416768                12.86
# 2                           45.134344                13.91
# 3                           35.265942                13.80
# 4                           28.556142                13.25
# ..                                ...                  ...
# 254                         24.816602                21.78
# 255                         22.393849                21.95
# 256                          8.044518                21.84
# 257                          8.340969                21.65
# 258                          8.304691                22.03
#
#      Environmental Flow Requirements  GDP per capita  \
# 0                             28.290      248.518890
# 1                             28.290      164.092893
# 2                             28.290      194.958382
# 3                             28.290      389.985586
# 4                             28.290      694.885618
# ..                               ...             ...
# 254                            9.348      657.209841
# 255                            9.348      522.006175
# 256                            9.348     1163.418688
# 257                            9.348     1333.395663
# 258                            9.348     1437.425967
#
#      Industry, value added to GDP  \
# 0                    5.530000e+08
# 1                    4.220000e+08
# 2                    9.150000e+08
# 3                    2.600000e+09
# 4                    4.360000e+09
# ..                            ...
# 254                  8.860000e+08
# 255                  1.900000e+09
# 256                  3.840000e+09
# 257                  4.190000e+09
# 258                  4.490000e+09
#
#      Long-term average annual precipitation in volume  \
# 0                                           213.48522
# 1                                           213.48522
# 2                                           213.48522
# 3                                           213.48522
# 4                                           213.48522
# ..                                                ...
# 254                                         256.72932
# 255                                         256.72932
# 256                                         256.72932
# 257                                         256.72932
# 258                                         256.72932
#
#      MDG 7.5. Freshwater withdrawal as % of total renewable water resources  \
# 0                                            35.910480
# 1                                            31.852952
# 2                                            31.045461
# 3                                            31.045461
# 4                                            31.045461
# ..                                                 ...
# 254                                          21.025000
# 255                                          17.850000
# 256                                          17.303125
# 257                                          16.695000
# 258                                          18.856900
#
#      ...  SDG 6.4.1. Industrial Water Use Efficiency  \
# 0    ...                                   25.311413
# 1    ...                                    9.091408
# 2    ...                                   11.426285
# 3    ...                                   20.815284
# 4    ...                                   23.227115
# ..   ...                                         ...
# 254  ...                                    3.517161
# 255  ...                                    9.827918
# 256  ...                                   32.078736
# 257  ...                                   49.212382
# 258  ...                                   50.133261
#
#      SDG 6.4.1. Irrigated Agriculture Water Use Efficiency  \
# 0                                             0.092143
# 1                                             0.085820
# 2                                             0.074770
# 3                                             0.110353
# 4                                             0.103801
# ..                                                 ...
# 254                                           0.061777
# 255                                           0.044898
# 256                                           0.040073
# 257                                           0.045300
# 258                                           0.042805
#
#      SDG 6.4.1. Services Water Use Efficiency  \
# 0                                   10.237171
# 1                                    7.763338
# 2                                   15.252615
# 3                                   26.876683
# 4                                   47.639557
# ..                                        ...
# 254                                  9.589117
# 255                                  8.137430
# 256                                 19.655079
# 257                                 27.194410
# 258                                 21.585173
#
#      SDG 6.4.1. Water Use Efficiency  SDG 6.4.2. Water Stress  \
# 0                           0.240400                63.337788
# 1                           0.194590                56.181246
# 2                           0.285607                54.757019
# 3                           0.549846                54.757019
# 4                           0.770774                54.757019
# ..                               ...                      ...
# 254                         1.641160                39.476155
# 255                         1.597468                33.514833
# 256                         4.396704                32.488030
# 257                         5.209213                31.346226
# 258                         4.830176                35.405370
#
#      Services, value added to GDP  \
# 0                    9.950000e+08
# 1                    6.530000e+08
# 2                    1.470000e+09
# 3                    4.030000e+09
# 4                    1.070000e+10
# ..                            ...
# 254                  4.770000e+09
# 255                  3.100000e+09
# 256                  9.920000e+09
# 257                  1.390000e+10
# 258                  1.540000e+10
#
#      Total population with access to safe drinking-water (JMP)  \
# 0                                                 21.3
# 1                                                 25.0
# 2                                                 33.8
# 3                                                 42.6
# 4                                                 51.6
# ..                                                 ...
# 254                                               79.4
# 255                                               78.4
# 256                                               77.5
# 257                                               76.9
# 258                                               76.9
#
#      Total renewable water resources per capita  \
# 0                                   4510.012947
# 1                                   3374.984489
# 2                                   2890.609479
# 3                                   2410.653428
# 4                                   2096.505623
# ..                                          ...
# 254                                 1673.039553
# 255                                 1631.864171
# 256                                 1524.953965
# 257                                 1404.830298
# 258                                 1385.156469
#
#      Total water withdrawal per capita  Gross Domestic Product (GDP)
# 0                          1619.567311                  3.444711e+09
# 1                          1075.032191                  2.924589e+09
# 2                           899.030431                  4.141524e+09
# 3                           751.752659                  9.412162e+09
# 4                           653.786919                  1.913650e+10
# ..                                 ...                           ...
# 254                         351.756566                  8.215468e+09
# 255                         291.287755                  6.958295e+09
# 256                         263.898049                  1.711485e+10
# 257                         234.543442                  2.204090e+10
# 258                         261.197570                  2.431156e+10
#
# [259 rows x 22 columns]

# %%
df.rename(columns = {'SDG 6.4.2. Water Stress':'WaterStress'}, inplace = True)

# %%
df['Industry, value added (% GDP)']=df['Industry, value added to GDP']/df['Gross Domestic Product (GDP)']*100
df['Services, value added (% GDP)']=df['Services, value added to GDP']/df['Gross Domestic Product (GDP)']*100

# %%
df['WaterStress']
# Out:
# 0      63.337788
# 1      56.181246
# 2      54.757019
# 3      54.757019
# 4      54.757019
#          ...
# 254    39.476155
# 255    33.514833
# 256    32.488030
# 257    31.346226
# 258    35.405370
# Name: WaterStress, Length: 259, dtype: float64

# %%
df.isnull().sum()
# Out:
# Area                                                                       0
# Year                                                                       0
# Agricultural water withdrawal as % of total renewable water resources      7
# Agriculture, value added (% GDP)                                           0
# Average Temperature                                                        4
# Environmental Flow Requirements                                            0
# GDP per capita                                                             0
# Industry, value added to GDP                                               0
# Long-term average annual precipitation in volume                           0
# MDG 7.5. Freshwater withdrawal as % of total renewable water resources     5
# National Rainfall Index (NRI)                                              7
# Population density                                                         0
# SDG 6.4.1. Industrial Water Use Efficiency                                 8
# SDG 6.4.1. Irrigated Agriculture Water Use Efficiency                     43
# SDG 6.4.1. Services Water Use Efficiency                                  10
# SDG 6.4.1. Water Use Efficiency                                           45
# WaterStress                                                                5
# Services, value added to GDP                                               0
# Total population with access to safe drinking-water (JMP)                  4
# Total renewable water resources per capita                                 0
# Total water withdrawal per capita                                          5
# Gross Domestic Product (GDP)                                               0
# Industry, value added (% GDP)                                              0
# Services, value added (% GDP)                                              0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
df.columns = df.columns.str.replace('%', 'per')

# %%
df.columns = df.columns.str.replace(',', '')
df.columns = df.columns.str.replace('(', '')
df.columns = df.columns.str.replace(')', '')
df.columns = df.columns.str.replace('.', '')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   after removing the cwd from sys.path.

# %%
for col in df.columns:
    print(col)
# Out:
# Area
# Year
# Agricultural_water_withdrawal_as_per_of_total_renewable_water_resources
# Agriculture__value_added_per_GDP
# Average_Temperature
# Environmental_Flow_Requirements
# GDP_per_capita
# Industry__value_added_to_GDP
# Long-term_average_annual_precipitation_in_volume
# MDG_75_Freshwater_withdrawal_as_per_of_total_renewable_water_resources
# National_Rainfall_Index_NRI
# Population_density
# SDG_641_Industrial_Water_Use_Efficiency
# SDG_641_Irrigated_Agriculture_Water_Use_Efficiency
# SDG_641_Services_Water_Use_Efficiency
# SDG_641_Water_Use_Efficiency
# WaterStress
# Services__value_added_to_GDP
# Total_population_with_access_to_safe_drinking-water_JMP
# Total_renewable_water_resources_per_capita
# Total_water_withdrawal_per_capita
# Gross_Domestic_Product_GDP
# Industry__value_added_per_GDP
# Services__value_added_per_GDP

# %%
md = smf.mixedlm("WaterStress ~ Year+Agriculture__value_added_per_GDP+GDP_per_capita+Industry__value_added_per_GDP+Services__value_added_per_GDP+Average_Temperature+Environmental_Flow_Requirements+SDG_641_Water_Use_Efficiency+National_Rainfall_Index_NRI", df, groups=df["Area"])
mdf = md.fit()
print(mdf.summary())
# Out:
#                       Mixed Linear Model Regression Results
# =================================================================================
# Model:                    MixedLM         Dependent Variable:         WaterStress
# No. Observations:         208             Method:                     REML
# No. Groups:               36              Scale:                      33.6603
# Min. group size:          3               Likelihood:                 -770.4194
# Max. group size:          7               Converged:                  Yes
# Mean group size:          5.8
# ---------------------------------------------------------------------------------
#                                   Coef.   Std.Err.   z    P>|z|  [0.025   0.975]
# ---------------------------------------------------------------------------------
# Intercept                        -411.687  157.388 -2.616 0.009 -720.161 -103.213
# Year                                0.251    0.078  3.206 0.001    0.098    0.405
# Agriculture__value_added_per_GDP    0.151    0.168  0.902 0.367   -0.177    0.480
# GDP_per_capita                     -0.000    0.000 -3.091 0.002   -0.001   -0.000
# Industry__value_added_per_GDP       0.120    0.137  0.870 0.384   -0.150    0.389
# Services__value_added_per_GDP      -0.254    0.133 -1.902 0.057   -0.515    0.008
# Average_Temperature                -1.112    0.628 -1.770 0.077   -2.343    0.119
# Environmental_Flow_Requirements     0.001    0.002  0.250 0.803   -0.004    0.005
# SDG_641_Water_Use_Efficiency       -0.118    0.037 -3.157 0.002   -0.191   -0.045
# National_Rainfall_Index_NRI        -0.019    0.006 -3.070 0.002   -0.032   -0.007
# Group Var                         982.316   49.881
# =================================================================================
